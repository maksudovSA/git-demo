# %% [markdown]
# # Prime Numbers

# %%
#@title ### Run the following cell to download the necessary files for this practical { display-mode: "form" }
#@markdown Don't worry about what's in this collapsed cell

# !pip install -q timeout-decorator
print('Downloading the marking system')
# !wget https://s3-eu-west-1.amazonaws.com/aicore-portal-public-prod-307050600709/practical_files/67cb68ea-4505-4cd6-8b71-8cb621c2525e/marking_system.py -q -O marking_system.py
import marking_system
import importlib
importlib.reload(marking_system)
import sys
ipython = get_ipython()
def hide_traceback(exc_tuple=None, filename=None, tb_offset=None, exception_only=False, running_compiled_code=False):
    etype, value, tb = sys.exc_info()
    value.__cause__ = None  # suppress chained exceptions
    return ipython._showtraceback(etype, "❌ " + f"[91m{value}", ipython.InteractiveTB.get_exception_only(etype, "❌ " + f"[91m{value}"))
ipython.showtraceback = hide_traceback
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for timeout-decorator (setup.py) ... done
# Downloading the marking system

# %% [markdown]
# ### 1. Write a program to check whether each number from 10 to 300 is prime
#
# There are different ways to tackle this problem. For now, let's see a simple way to do it.
#
# 1. We will use a `for` loop to iterate over the numbers from 10 to 300.
# 2. Inside the `for` loop, we will use another `for` loop to iterate over the numbers from 2 to the number we are checking.
# 3. We will check if the number we are checking is divisible by any of the numbers from 2 to the number we are checking.
# 4. If the number is divisible by any of the numbers from 2 to the number we are checking, we will print that the number is not prime: `"{number} is not a prime number because it is divisible by y."`
# 5. If the number is not divisible by any of the numbers from 2 to the number we are checking, we will print that the number is prime. `"{number} is a prime number."`

# %%
# Add your code below this line
# TODO - Create a for loop that iterates over the numbers 10 to 300
    # TODO - Create a for loop that iterates over the numbers 2 to current number in the outer loop
# TODO - Check if the current number in the outer loop is divisible by the current number in the inner loop. If it is, print that it is not a prime number and break out of the inner loop
    # TODO - If the number is not divisible by any number in the inner loop, print that it is a prime number
        # TODO - If the number is not divisible by any number in the inner loop, print that it is a prime number
# Iterate over the numbers from 10 to 300
for number in range(10, 301):
    is_prime = True  # Assume the number is prime initially

    # Iterate over the numbers from 2 to the number being checked
    for divisor in range(2, number):
        if number % divisor == 0:
            # Number is divisible by divisor, so it's not prime
            print(f"{number} is not a prime number because it is divisible by {divisor}.")
            is_prime = False
            break  # No need to continue checking divisors

    # If the number is not divisible by any divisor, it's prime
    if is_prime:
        print(f"{number} is a prime number.")
# Out:
# 10 is not a prime number because it is divisible by 2.
# 11 is a prime number.
# 12 is not a prime number because it is divisible by 2.
# 13 is a prime number.
# 14 is not a prime number because it is divisible by 2.
# 15 is not a prime number because it is divisible by 3.
# 16 is not a prime number because it is divisible by 2.
# 17 is a prime number.
# 18 is not a prime number because it is divisible by 2.
# 19 is a prime number.
# 20 is not a prime number because it is divisible by 2.
# 21 is not a prime number because it is divisible by 3.
# 22 is not a prime number because it is divisible by 2.
# 23 is a prime number.
# 24 is not a prime number because it is divisible by 2.
# 25 is not a prime number because it is divisible by 5.
# 26 is not a prime number because it is divisible by 2.
# 27 is not a prime number because it is divisible by 3.
# 28 is not a prime number because it is divisible by 2.
# 29 is a prime number.
# 30 is not a prime number because it is divisible by 2.
# 31 is a prime number.
# 32 is not a prime number because it is divisible by 2.
# 33 is not a prime number because it is divisible by 3.
# 34 is not a prime number because it is divisible by 2.
# 35 is not a prime number because it is divisible by 5.
# 36 is not a prime number because it is divisible by 2.
# 37 is a prime number.
# 38 is not a prime number because it is divisible by 2.
# 39 is not a prime number because it is divisible by 3.
# 40 is not a prime number because it is divisible by 2.
# 41 is a prime number.
# 42 is not a prime number because it is divisible by 2.
# 43 is a prime number.
# 44 is not a prime number because it is divisible by 2.
# 45 is not a prime number because it is divisible by 3.
# 46 is not a prime number because it is divisible by 2.
# 47 is a prime number.
# 48 is not a prime number because it is divisible by 2.
# 49 is not a prime number because it is divisible by 7.
# 50 is not a prime number because it is divisible by 2.
# 51 is not a prime number because it is divisible by 3.
# 52 is not a prime number because it is divisible by 2.
# 53 is a prime number.
# 54 is not a prime number because it is divisible by 2.
# 55 is not a prime number because it is divisible by 5.
# 56 is not a prime number because it is divisible by 2.
# 57 is not a prime number because it is divisible by 3.
# 58 is not a prime number because it is divisible by 2.
# 59 is a prime number.
# 60 is not a prime number because it is divisible by 2.
# 61 is a prime number.
# 62 is not a prime number because it is divisible by 2.
# 63 is not a prime number because it is divisible by 3.
# 64 is not a prime number because it is divisible by 2.
# 65 is not a prime number because it is divisible by 5.
# 66 is not a prime number because it is divisible by 2.
# 67 is a prime number.
# 68 is not a prime number because it is divisible by 2.
# 69 is not a prime number because it is divisible by 3.
# 70 is not a prime number because it is divisible by 2.
# 71 is a prime number.
# 72 is not a prime number because it is divisible by 2.
# 73 is a prime number.
# 74 is not a prime number because it is divisible by 2.
# 75 is not a prime number because it is divisible by 3.
# 76 is not a prime number because it is divisible by 2.
# 77 is not a prime number because it is divisible by 7.
# 78 is not a prime number because it is divisible by 2.
# 79 is a prime number.
# 80 is not a prime number because it is divisible by 2.
# 81 is not a prime number because it is divisible by 3.
# 82 is not a prime number because it is divisible by 2.
# 83 is a prime number.
# 84 is not a prime number because it is divisible by 2.
# 85 is not a prime number because it is divisible by 5.
# 86 is not a prime number because it is divisible by 2.
# 87 is not a prime number because it is divisible by 3.
# 88 is not a prime number because it is divisible by 2.
# 89 is a prime number.
# 90 is not a prime number because it is divisible by 2.
# 91 is not a prime number because it is divisible by 7.
# 92 is not a prime number because it is divisible by 2.
# 93 is not a prime number because it is divisible by 3.
# 94 is not a prime number because it is divisible by 2.
# 95 is not a prime number because it is divisible by 5.
# 96 is not a prime number because it is divisible by 2.
# 97 is a prime number.
# 98 is not a prime number because it is divisible by 2.
# 99 is not a prime number because it is divisible by 3.
# 100 is not a prime number because it is divisible by 2.
# 101 is a prime number.
# 102 is not a prime number because it is divisible by 2.
# 103 is a prime number.
# 104 is not a prime number because it is divisible by 2.
# 105 is not a prime number because it is divisible by 3.
# 106 is not a prime number because it is divisible by 2.
# 107 is a prime number.
# 108 is not a prime number because it is divisible by 2.
# 109 is a prime number.
# 110 is not a prime number because it is divisible by 2.
# 111 is not a prime number because it is divisible by 3.
# 112 is not a prime number because it is divisible by 2.
# 113 is a prime number.
# 114 is not a prime number because it is divisible by 2.
# 115 is not a prime number because it is divisible by 5.
# 116 is not a prime number because it is divisible by 2.
# 117 is not a prime number because it is divisible by 3.
# 118 is not a prime number because it is divisible by 2.
# 119 is not a prime number because it is divisible by 7.
# 120 is not a prime number because it is divisible by 2.
# 121 is not a prime number because it is divisible by 11.
# 122 is not a prime number because it is divisible by 2.
# 123 is not a prime number because it is divisible by 3.
# 124 is not a prime number because it is divisible by 2.
# 125 is not a prime number because it is divisible by 5.
# 126 is not a prime number because it is divisible by 2.
# 127 is a prime number.
# 128 is not a prime number because it is divisible by 2.
# 129 is not a prime number because it is divisible by 3.
# 130 is not a prime number because it is divisible by 2.
# 131 is a prime number.
# 132 is not a prime number because it is divisible by 2.
# 133 is not a prime number because it is divisible by 7.
# 134 is not a prime number because it is divisible by 2.
# 135 is not a prime number because it is divisible by 3.
# 136 is not a prime number because it is divisible by 2.
# 137 is a prime number.
# 138 is not a prime number because it is divisible by 2.
# 139 is a prime number.
# 140 is not a prime number because it is divisible by 2.
# 141 is not a prime number because it is divisible by 3.
# 142 is not a prime number because it is divisible by 2.
# 143 is not a prime number because it is divisible by 11.
# 144 is not a prime number because it is divisible by 2.
# 145 is not a prime number because it is divisible by 5.
# 146 is not a prime number because it is divisible by 2.
# 147 is not a prime number because it is divisible by 3.
# 148 is not a prime number because it is divisible by 2.
# 149 is a prime number.
# 150 is not a prime number because it is divisible by 2.
# 151 is a prime number.
# 152 is not a prime number because it is divisible by 2.
# 153 is not a prime number because it is divisible by 3.
# 154 is not a prime number because it is divisible by 2.
# 155 is not a prime number because it is divisible by 5.
# 156 is not a prime number because it is divisible by 2.
# 157 is a prime number.
# 158 is not a prime number because it is divisible by 2.
# 159 is not a prime number because it is divisible by 3.
# 160 is not a prime number because it is divisible by 2.
# 161 is not a prime number because it is divisible by 7.
# 162 is not a prime number because it is divisible by 2.
# 163 is a prime number.
# 164 is not a prime number because it is divisible by 2.
# 165 is not a prime number because it is divisible by 3.
# 166 is not a prime number because it is divisible by 2.
# 167 is a prime number.
# 168 is not a prime number because it is divisible by 2.
# 169 is not a prime number because it is divisible by 13.
# 170 is not a prime number because it is divisible by 2.
# 171 is not a prime number because it is divisible by 3.
# 172 is not a prime number because it is divisible by 2.
# 173 is a prime number.
# 174 is not a prime number because it is divisible by 2.
# 175 is not a prime number because it is divisible by 5.
# 176 is not a prime number because it is divisible by 2.
# 177 is not a prime number because it is divisible by 3.
# 178 is not a prime number because it is divisible by 2.
# 179 is a prime number.
# 180 is not a prime number because it is divisible by 2.
# 181 is a prime number.
# 182 is not a prime number because it is divisible by 2.
# 183 is not a prime number because it is divisible by 3.
# 184 is not a prime number because it is divisible by 2.
# 185 is not a prime number because it is divisible by 5.
# 186 is not a prime number because it is divisible by 2.
# 187 is not a prime number because it is divisible by 11.
# 188 is not a prime number because it is divisible by 2.
# 189 is not a prime number because it is divisible by 3.
# 190 is not a prime number because it is divisible by 2.
# 191 is a prime number.
# 192 is not a prime number because it is divisible by 2.
# 193 is a prime number.
# 194 is not a prime number because it is divisible by 2.
# 195 is not a prime number because it is divisible by 3.
# 196 is not a prime number because it is divisible by 2.
# 197 is a prime number.
# 198 is not a prime number because it is divisible by 2.
# 199 is a prime number.
# 200 is not a prime number because it is divisible by 2.
# 201 is not a prime number because it is divisible by 3.
# 202 is not a prime number because it is divisible by 2.
# 203 is not a prime number because it is divisible by 7.
# 204 is not a prime number because it is divisible by 2.
# 205 is not a prime number because it is divisible by 5.
# 206 is not a prime number because it is divisible by 2.
# 207 is not a prime number because it is divisible by 3.
# 208 is not a prime number because it is divisible by 2.
# 209 is not a prime number because it is divisible by 11.
# 210 is not a prime number because it is divisible by 2.
# 211 is a prime number.
# 212 is not a prime number because it is divisible by 2.
# 213 is not a prime number because it is divisible by 3.
# 214 is not a prime number because it is divisible by 2.
# 215 is not a prime number because it is divisible by 5.
# 216 is not a prime number because it is divisible by 2.
# 217 is not a prime number because it is divisible by 7.
# 218 is not a prime number because it is divisible by 2.
# 219 is not a prime number because it is divisible by 3.
# 220 is not a prime number because it is divisible by 2.
# 221 is not a prime number because it is divisible by 13.
# 222 is not a prime number because it is divisible by 2.
# 223 is a prime number.
# 224 is not a prime number because it is divisible by 2.
# 225 is not a prime number because it is divisible by 3.
# 226 is not a prime number because it is divisible by 2.
# 227 is a prime number.
# 228 is not a prime number because it is divisible by 2.
# 229 is a prime number.
# 230 is not a prime number because it is divisible by 2.
# 231 is not a prime number because it is divisible by 3.
# 232 is not a prime number because it is divisible by 2.
# 233 is a prime number.
# 234 is not a prime number because it is divisible by 2.
# 235 is not a prime number because it is divisible by 5.
# 236 is not a prime number because it is divisible by 2.
# 237 is not a prime number because it is divisible by 3.
# 238 is not a prime number because it is divisible by 2.
# 239 is a prime number.
# 240 is not a prime number because it is divisible by 2.
# 241 is a prime number.
# 242 is not a prime number because it is divisible by 2.
# 243 is not a prime number because it is divisible by 3.
# 244 is not a prime number because it is divisible by 2.
# 245 is not a prime number because it is divisible by 5.
# 246 is not a prime number because it is divisible by 2.
# 247 is not a prime number because it is divisible by 13.
# 248 is not a prime number because it is divisible by 2.
# 249 is not a prime number because it is divisible by 3.
# 250 is not a prime number because it is divisible by 2.
# 251 is a prime number.
# 252 is not a prime number because it is divisible by 2.
# 253 is not a prime number because it is divisible by 11.
# 254 is not a prime number because it is divisible by 2.
# 255 is not a prime number because it is divisible by 3.
# 256 is not a prime number because it is divisible by 2.
# 257 is a prime number.
# 258 is not a prime number because it is divisible by 2.
# 259 is not a prime number because it is divisible by 7.
# 260 is not a prime number because it is divisible by 2.
# 261 is not a prime number because it is divisible by 3.
# 262 is not a prime number because it is divisible by 2.
# 263 is a prime number.
# 264 is not a prime number because it is divisible by 2.
# 265 is not a prime number because it is divisible by 5.
# 266 is not a prime number because it is divisible by 2.
# 267 is not a prime number because it is divisible by 3.
# 268 is not a prime number because it is divisible by 2.
# 269 is a prime number.
# 270 is not a prime number because it is divisible by 2.
# 271 is a prime number.
# 272 is not a prime number because it is divisible by 2.
# 273 is not a prime number because it is divisible by 3.
# 274 is not a prime number because it is divisible by 2.
# 275 is not a prime number because it is divisible by 5.
# 276 is not a prime number because it is divisible by 2.
# 277 is a prime number.
# 278 is not a prime number because it is divisible by 2.
# 279 is not a prime number because it is divisible by 3.
# 280 is not a prime number because it is divisible by 2.
# 281 is a prime number.
# 282 is not a prime number because it is divisible by 2.
# 283 is a prime number.
# 284 is not a prime number because it is divisible by 2.
# 285 is not a prime number because it is divisible by 3.
# 286 is not a prime number because it is divisible by 2.
# 287 is not a prime number because it is divisible by 7.
# 288 is not a prime number because it is divisible by 2.
# 289 is not a prime number because it is divisible by 17.
# 290 is not a prime number because it is divisible by 2.
# 291 is not a prime number because it is divisible by 3.
# 292 is not a prime number because it is divisible by 2.
# 293 is a prime number.
# 294 is not a prime number because it is divisible by 2.
# 295 is not a prime number because it is divisible by 5.
# 296 is not a prime number because it is divisible by 2.
# 297 is not a prime number because it is divisible by 3.
# 298 is not a prime number because it is divisible by 2.
# 299 is not a prime number because it is divisible by 13.
# 300 is not a prime number because it is divisible by 2.

# %%
#@title #### Run this cell to check if your code looks good { display-mode: "form"}
assert "# Add your code below this line" in _ih[-2], "Before checking your code, make sure the last cell you ran contains your code. If you did, make sure you haven't deleted the comment that says '# Add your code below this line'."
assert "#@title" not in _ih[-2], "If you want to check your code, rerun the cell that contains your code. If you did, make sure you haven't deleted the comment that says '# Add your code below this line'."

marking_system.check_step_1(_ih[-2])
# Out:
# ✔ Well done! You successfully checked whether all the numbers between 10 and 300 are prime numbers. This wasn't an easy task!

# %% [markdown]
# _There are other ways to check if a number is prime, but the above method is simple and easy to understand. Other methods would require advanced techniques like recursion._
